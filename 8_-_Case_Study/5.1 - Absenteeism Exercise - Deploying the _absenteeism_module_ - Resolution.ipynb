# %%
from absenteeism_module import *
model = absenteeism_model('model', 'scaler')

model.load_and_clean_data('./datasets/Absenteeism_new_data.csv')

model.predicted_outputs()
# Out:
# /home/luis/anaconda3/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.2 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /home/luis/anaconda3/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator StandardScaler from version 0.24.2 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
#     Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0          0       0.0         0         1            6
# 1          1       0.0         0         0            6
# 2          0       0.0         0         1            6
# 3          0       0.0         0         1            6
# 4          1       0.0         0         0            6
# 5          1       0.0         0         0            6
# ...

# %%
model.predicted_outputs().to_csv('./datasets/Absenteeism_predictions.csv', index = False)

# %%
predicted_df = model.predicted_outputs()
predicted_df.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0         0       0.0         0         1            6
# 1         1       0.0         0         0            6
# 2         0       0.0         0         1            6
# 3         0       0.0         0         1            6
# 4         1       0.0         0         0            6
#
#    Transportation Expense  Age  Body Mass Index  Education  Children  Pet  \
# 0                     179   30               19          1         0    0
# 1                     361   28               27          0         1    4
# 2                     155   34               25          0         2    0
# 3                     179   40               22          1         2    0
# 4                     155   34               25          0         2    0
#
#    Probability  Prediction
# 0     0.122469           0
# 1     0.873365           1
# 2     0.266253           0
# 3     0.198570           0
# 4     0.720861           1

# %% [markdown]
# ## Analysis

# %%
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

# %%
x = predicted_df['Age']
y = predicted_df['Probability']*100

plt.scatter(x, y)

plt.title('Age vs. Probability')
plt.xlabel('Age')
plt.ylabel('Probability')

plt.show()

# %%
x1 = predicted_df['Reason_1']
x2 = predicted_df['Reason_2']
x3 = predicted_df['Reason_3']
x4 = predicted_df['Reason_4']
y = predicted_df['Probability']*100

fig, axs = plt.subplots(1, 4, figsize=(9, 4), sharey=True)
axs[0].scatter(x1, y)
axs[0].set_xlabel('Reason_1')
axs[0].set_ylabel('Probability')
axs[1].scatter(x2, y)
axs[1].set_xlabel('Reason_2')
axs[2].scatter(x3, y)
axs[2].set_xlabel('Reason_3')
axs[3].scatter(x4, y)
axs[3].set_xlabel('Reason_4')

fig.suptitle('Reasons vs. Probability')

# plt.xlabel('Age')
# plt.ylabel('Probability')
# Out:
# Text(0.5, 0.98, 'Reasons vs. Probability')

# %%
x = predicted_df['Transportation Expense']
children = predicted_df['Children']**2*100
y = predicted_df['Probability']*100

plt.scatter(x, y, s=children)

plt.title('Transportation Expense and Children vs. Probability')
plt.xlabel('Transportation Expense')
plt.ylabel('Probability')

plt.show()
